# %%
class HelloWorld:
    # ===== Class: Hello World =======#
    # Class Variables:
    # - message: str -> message to be displayed


    # Args: None.
    # Returns: None
    def __init__(self, message :str = "Hello World!"):
        #  constructor

        raise NotImplementedError
     
    # Args: None
    # Returns: str with message 
    def __repr__(self) -> str:
       
        raise NotImplementedError

# %% [markdown]
# ### Let's test the Hello World Class

# %%
smiley_face = HelloWorld()
smiley_face
# Out:
# Hello World!

# %%
sad_face = HelloWorld("Goodbye world.")
sad_face
# Out:
# Goodbye world.

# %% [markdown]
# Looks good to me!
